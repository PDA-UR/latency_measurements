# %%
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import os
import numpy as np

# %%
DATA_PATH = "./"
ITERATIONS = ["_1","_2","_3","_4","_5"]

#Device Arrays as needed for plotting

#All Devices
DEVICES = ["6312kw", "adns5700", "apple1152","arduino", "bt58", "diamondback", "dragonrise_black", "dragonrise_green", "dualshock3_wired", "dualshock4_wired", "dualshock4_wireless",
           "exxter", "g15", "g300", "g5", "g700_wired", "g700_wireless", "gembird", "intelli_new", "intelli_og", "k120", "logilink0043", "nixdorf", "nvidiashield", "nvidiashield_wireless", "px1800", "rapoo", "rival", "roccat", "rx250", "sigma", "sk9620", "sunplus", "tramani_wired", "trust_oni_wireless", "unicomp", "wingman", "xbox360_wired", "xbox360_wireless", "xboxone_wireless"]

#Only Mice
DEVICES = ["bt58","rival","intelli_new","intelli_og","apple1152","sunplus","g5","g300","rapoo",
           "trust_oni_wireless", "adns5700","logilink0043","diamondback","rx250","g700"]

#Only Keyboards
DEVICES = ["k120", "6312kw","nixdorf","sigma","exxter","px1800","gembird","g15","sk9620","roccat","unicomp"]

#Only Gamepads excluding arduino
DEVICES = ["dragonrise_green","wingman","dragonrise_black","xboxone_wireless","dualshock4_wired",
           "xbox360_wireless","tramani_wired","dualshock3_wired","xbox360_wired","nvidiashield"]

#Devices with odd Data
#DEVICES = ["diamondback", "exxter", "arduino"]


#TODO xbox360_wired polling rate
POLLING_RATES = {"6312kw" : -1, "adns5700" : 10, "apple1152" : 10, "arduino" : 1, 
                 "bt58" : 10, "diamondback" : 10, "dragonrise_black" : 10, "dragonrise_green" : 10, 
                 "dualshock3_wired" : 1, "dualshock4_wired" : 5, "dualshock4_wireless" : -1, "exxter" : 10, 
                 "g15" : 24, "g300" : 1, "g5" : 10, "g700_wired" : 1, "g700_wireless" : -1, "gembird" : 10, 
                 "intelli_new" : 1, "intelli_og" : -1, "k120" : 10, "logilink0043" : 10, "nixdorf" : -1, 
                 "nvidiashield" : 1, "nvidiashield_wireless" : -1, "px1800" : 10, "rapoo" : -1, "rival" : 1, 
                 "roccat" : 1, "rx250" : 10, "sigma" : 10, "sk9620" : -1, "sunplus" : 10, 
                 "tramani_wired" : 10, "trust_oni_wireless" : 10, "unicomp" : 10, "wingman" : 10, 
                 "xbox360_wired" : -1, "xbox360_wireless" : -1, "xboxone_wireless" : -1}

DEVICE_NAMES ={
"Acer 6312-KW"
"Microsoft Optical Mouse 200"
"Apple A1152"
"Arduino Micro"
"Logitech Premium Optical Wheel Mouse"
"Razord Diamondback"
"Speedlink Strike"
"Speedlink Strike"
"Sony Dualshock 3"
"Sony Dualshock 4"
"Exxter KE-200"
"Logitech G15"
"Logitech G300"
"Logitech G5"
"Logitech G700"
"Gembird"
"Microsoft Classic Intellimo"use
"Microsoft Intellimous"e
"Logitech K120"
"LogiLink ID0043"
"Siemens Nixdorf"
"nVidia Shield"
"PX-1800"
"Rapoo 6010B"
"Steel Series Rival Optical Mouse"
"Roccat ISKU FX"
"Logitech RX250"
"?"
"Acer SK-9620"
"MS-TECH Laser Game Mouse"
"Tramani CT-P3000"
"Trust Oni Wireless Micro Mouse"
"Unicomp Keyboard"
"Logitech Wingman"
"XBox 360 wired"
"XBox 360"
"XBox One Controller"
    }

MODES = ["default_polling", "1ms_polling"]

all_raw_data = []

#print(os.system("ls"))

for device in DEVICES:
    for mode in MODES:
        for iteration in ITERATIONS:
            if mode == "default_polling":
                path = DATA_PATH + mode + "/" + "AUTO_" + device + "_0ms" + iteration +".csv"
                try:
                    #print(path)
                    currentFile = pd.read_csv(path, comment="#", delimiter=';')
                except:
                    print("file missing: ", path)
                currentFile["device"] = device
                
                label = POLLING_RATES[device]
                if(label == -1):
                    label = "unknown"
                label = "default {}ms".format(label)
                currentFile["polling"] = label
            else:
                path = DATA_PATH + mode + "/" + "AUTO_" + device + "_1ms" + iteration +".csv"
                try:
                    currentFile = pd.read_csv(path, comment="#", delimiter=';')
                except:
                    print("file missing: ", path)
                currentFile["device"] = device
                currentFile["polling"] = "forced 1ms"
            #print(type(currentFile))
            #print(len(currentFile))
            #print(currentFile)
            all_raw_data.append(currentFile)
all_data = pd.concat(all_raw_data)
#all_data["latency (ms)"] = all_data["latency (s)"] * 1000.0
# Out:
#   File "<ipython-input-23-20f6dc95e833>", line 46
#     "Logitech RX250", "nVidia Shield", "Logitech G700", "Acer SK-9620", "Roccat ISKU FX", "
#                                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
sorted(list(all_data["latency"]))[-10:]
# Out:
# [13808, 13810, 13827, 13870, 13985, 14460, 17640, 27944, 53248, 176817]

# %%
MAX_LATENCY = 100000 # microseconds
values = all_data[(all_data["device"]) == "diamondback"]
values = values[values["latency"]<=MAX_LATENCY]
plt.title('Swarmplot of '+ device)

ax = sns.pointplot((values["latency"]/1000), values["polling"], join=False, palette="dark", markers="D", scale=.75, ci="sd", zorder=1, errwidth=0.5, capsize=.2)
ax = sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="colorblind", size=1, dodge=True, marker="H",orient="h", alpha=1, zorder=0)

#plt.savefig("svg/test1.svg")
#plt.savefig("png/test1.png")

# %%
# Out:
# 6312kw
# adns5700
# apple1152
# bt58
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-129b17aa4437> in <module>()
#      25
#      26     #point_plot = sns.pointplot((values["latency"]/1000), values["polling"], join=False, palette="dark", markers="D", scale=.75, ci="sd", zorder=1, ax=axes[i], capsize=.2)
# ---> 27     swarm_plot = sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="colorblind", size=1, dodge=True, marker="H",orient="h", alpha=1, zorder=0, edgecolors='w', ax=axes[i])
#      28
#      29     POLLING_RATES[device]
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in draw_swarmplot(self, ax, kws)
#    1429         for center, swarm in zip(centers, swarms):
#    1430             if swarm.get_offsets().size:
# -> 1431                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1432
#    1433     def plot(self, ax, kws):
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in swarm_points(self, ax, points, center, width, s, **kws)
#    1338
#    1339         # Do the beeswarm in point coordinates
# -> 1340         new_xy = self.beeswarm(orig_xy, d)
#    1341
#    1342         # Transform the point coordinates back to data coordinates
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in beeswarm(self, orig_xy, d)
#    1300             # Find the first candidate that doesn't overlap any neighbours
#    1301             new_xy_i = self.first_non_overlapping_candidate(candidates,
# -> 1302                                                             neighbors, d)
#    1303
#    1304             # Place it into the swarm
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in first_non_overlapping_candidate(self, candidates, neighbors, d)
#    1264             # and any of the neighbours has to be at least
#    1265             # square of the diameter
# -> 1266             good_candidate = np.all(sq_distances >= d_square)
#    1267
#    1268             if good_candidate:
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in all(a, axis, out, keepdims)
#    2094     arr = asanyarray(a)
#    2095     kwargs = {}
# -> 2096     if keepdims is not np._NoValue:
#    2097         kwargs['keepdims'] = keepdims
#    2098     return arr.all(axis=axis, out=out, **kwargs)
#
# KeyboardInterrupt:

# %%
i = 0

import os
MAX_LATENCY = 100000 # microseconds



for device in DEVICES:
    #if(i < 4):
    #    continue
    fig, axes = plt.subplots(1, 1)
    fig.set_figheight(5)
    fig.set_figwidth(8)
    
    values = all_data[(all_data["device"]) == DEVICES[i]]
    
    values = values[values["latency"]<=MAX_LATENCY]
    
    plt.title(device)
    ax = sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="colorblind", size=1, dodge=True, marker="H",orient="h", alpha=1, zorder=0)
    ax.set_xlim(0, 50)
       
    
    i = i+1
    print(device)
    plt.savefig("png/{}.png".format(device), dpi=600)
    
    # automatically print it - use carefully!
    #os.system("lp png/{}.png".format(device))
    
    plt.close(fig)
    
    


#plt.savefig("svg/allDevices.svg")
#plt.savefig("png/allDevices.png")
# Out:
# diamondback
# exxter

# %%
print(len(DEVICES))
# Out:
# 2

# %%
#Plotting a single swarmplot

plt.figure(figsize=[16, 4])
#plt.title('Swarmplot of '+ values["device"])

#plt.figure()
sns.swarmplot(data=all_data, y="device", x="latency", hue=None, palette="Set2", size=1,orient="h", alpha=1, ax=axes[i],)

plt.xlabel("latency (ms)")
plt.xlim(0, 100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-fc8cad7c891f> in <module>()
#       5
#       6 #plt.figure()
# ----> 7 sns.swarmplot(data=all_data, y="device", x="latency", hue=None, palette="Set2", size=1,orient="h", alpha=1, ax=axes[i])
#       8 a
#       9 plt.xlabel("latency (ms)")
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in draw_swarmplot(self, ax, kws)
#    1429         for center, swarm in zip(centers, swarms):
#    1430             if swarm.get_offsets().size:
# -> 1431                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1432
#    1433     def plot(self, ax, kws):
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in swarm_points(self, ax, points, center, width, s, **kws)
#    1338
#    1339         # Do the beeswarm in point coordinates
# -> 1340         new_xy = self.beeswarm(orig_xy, d)
#    1341
#    1342         # Transform the point coordinates back to data coordinates
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in beeswarm(self, orig_xy, d)
#    1300             # Find the first candidate that doesn't overlap any neighbours
#    1301             new_xy_i = self.first_non_overlapping_candidate(candidates,
# -> 1302                                                             neighbors, d)
#    1303
#    1304             # Place it into the swarm
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in first_non_overlapping_candidate(self, candidates, neighbors, d)
#    1258             dy = neighbors_y - y_i
#    1259
# -> 1260             sq_distances = np.power(dx, 2.0) + np.power(dy, 2.0)
#    1261
#    1262             # good candidate does not overlap any of neighbors
#
# KeyboardInterrupt:

# %%
values = all_data[(all_data["device"] == "exxter")]


plt.figure(figsize=[16, 4])
#plt.title('Swarmplot of '+ values["device"])

ax = sns.pointplot((values["latency"]/1000), values["polling"], join=False, palette="dark", markers="D", scale=.75, ci="sd", zorder=1)
ax = sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="colorblind", size=1, dodge=True, marker="H",orient="h", alpha=1, zorder=0)

plt.xlabel("latency (ms)")
plt.xlim(0, 100)

axes = plt.gca()
#axes.set_xlim(0,100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-b0936ca2a473> in <module>()
#       6
#       7 ax = sns.pointplot((values["latency"]/1000), values["polling"], join=False, palette="dark", markers="D", scale=.75, ci="sd", zorder=1)
# ----> 8 ax = sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="colorblind", size=1, dodge=True, marker="H",orient="h", alpha=1, zorder=0)
#       9
#      10 plt.xlabel("latency (ms)")
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in draw_swarmplot(self, ax, kws)
#    1429         for center, swarm in zip(centers, swarms):
#    1430             if swarm.get_offsets().size:
# -> 1431                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1432
#    1433     def plot(self, ax, kws):
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in swarm_points(self, ax, points, center, width, s, **kws)
#    1338
#    1339         # Do the beeswarm in point coordinates
# -> 1340         new_xy = self.beeswarm(orig_xy, d)
#    1341
#    1342         # Transform the point coordinates back to data coordinates
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in beeswarm(self, orig_xy, d)
#    1300             # Find the first candidate that doesn't overlap any neighbours
#    1301             new_xy_i = self.first_non_overlapping_candidate(candidates,
# -> 1302                                                             neighbors, d)
#    1303
#    1304             # Place it into the swarm
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in first_non_overlapping_candidate(self, candidates, neighbors, d)
#    1258             dy = neighbors_y - y_i
#    1259
# -> 1260             sq_distances = np.power(dx, 2.0) + np.power(dy, 2.0)
#    1261
#    1262             # good candidate does not overlap any of neighbors
#
# KeyboardInterrupt:

# %%
#Plotting all devices in one picture
i = 0

#plt.xlim(0, 80)
fig, axes = plt.subplots((len(DEVICES)), 1)


fig.set_figheight(4 * len(DEVICES))
fig.set_figwidth(16)

#fig(xlim = [0,80])


#axes.set_xlabel("latency (ms)")
#axes = plt.gca()
#axes.set_xlim([0,80])



for device in DEVICES:
    values = all_data[(all_data["device"]) == DEVICES[i]]

    plt.title('Swarmplot of '+ device)
    #sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="Set2",size=1,orient="h",alpha=1, ax=axes[i])    
    
    #point_plot = sns.pointplot((values["latency"]/1000), values["polling"], join=False, palette="dark", markers="D", scale=.75, ci="sd", zorder=1, ax=axes[i], capsize=.2)
    swarm_plot = sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="colorblind", size=1, dodge=True, marker="H",orient="h", alpha=1, zorder=0, edgecolors='w', ax=axes[i])

    POLLING_RATES[device]
    
    axes[i].set_xlim(0, 40)
    i = i+1
    print(device)


plt.savefig("svg/allDevices.svg")
plt.savefig("png/allDevices.png")

# %%
#Plotting a single swarmplot
values = all_data[(all_data["device"] == "6312kw")]

plt.figure(figsize=[16, 8])
#plt.title('Swarmplot of '+ values["device"])

#plt.figure()

ax = sns.swarmplot((values["latency"]/1000), values["polling"], hue=None, palette="Set1", size=1,marker ="H", orient="h", alpha=1)
ax = sns.violinplot((values["latency"]/1000), values["polling"], inner=None, palette="Set2", split=True )
plt.xlabel("latency (ms)")
plt.xlim(0, 100)

#axes = plt.gca()
#axes.set_xlim(0,100)
# Out:
# (0, 100)
